# %%
import pandas as pd

# %%
countries=pd.read_csv(r"")
countries
# Out:
#         Country    Hydro   Biofuel  Solar PV  Geothermal (TWh)     Total
# 0         China  1189.84  295.0200     79.43            0.1250  1819.9400
# 1           USA   315.62  277.9100     58.95           18.9600   758.6190
# 2        Brazil   370.90   42.3700     52.25            0.0000   466.3500
# 3        Canada   383.48   29.6500      7.12            0.0000   424.0900
# 4         India   141.80   51.0600     43.76            0.0000   262.6500
# 5       Germany    24.17  111.5900     45.10            0.1600   227.1800
# 6        Russia   187.13    0.1400      0.08            0.4300   188.3300
# 7         Japan    90.67    7.6300     19.01            2.4400   187.3490
# 8        France    70.13   28.5000      5.87            0.1300   114.8200
# 9         Italy    50.92   17.4900     16.85            6.0800   113.9900
# 10           UK     7.96   57.1100     32.08            0.0000   110.0700
# 11        Spain    36.74   50.8100      5.48            0.0000   100.5400
# ...

# %% [markdown]
# # 2	List out the countries among top 20 Countries that don’t produce power from Geothermal means.

# %%
countries.loc[:,["Geothermal (TWh)","Country"]]
# Out:
#     Geothermal (TWh)      Country
# 0             0.1250        China
# 1            18.9600          USA
# 2             0.0000       Brazil
# 3             0.0000       Canada
# 4             0.0000        India
# 5             0.1600      Germany
# 6             0.4300       Russia
# 7             2.4400        Japan
# 8             0.1300       France
# 9             6.0800        Italy
# 10            0.0000           UK
# 11            0.0000        Spain
# 12            6.9000       Turkey
# 13            5.3600       Mexico
# 14            0.0000    Australia
# 15           12.7600    Indonesia
# 16            0.0001     Thailand
# 17            0.0000  South Korea
# 18            0.0000         Iran
# 19            0.0000       Taiwan

# %%
countries.groupby("Country")["Geothermal (TWh)"].sum().sort_values(ascending=True).head(10)
# Out:
# Country
# Australia      0.0000
# Brazil         0.0000
# Canada         0.0000
# India          0.0000
# Iran           0.0000
# UK             0.0000
# South Korea    0.0000
# Spain          0.0000
# Taiwan         0.0000
# Thailand       0.0001
# Name: Geothermal (TWh), dtype: float64

# %% [markdown]
# # 1	Show Top 5 countries with highest renewable energy generation.

# %%
countries.columns
# Out:
# Index(['Country', 'Hydro', 'Biofuel', 'Solar PV', 'Geothermal (TWh)',
#        'Total '],
#       dtype='object')

# %%
countrywisetotal=countries[["Country","Total "]]
countrywisetotal
# Out:
#         Country     Total
# 0         China  1819.9400
# 1           USA   758.6190
# 2        Brazil   466.3500
# 3        Canada   424.0900
# 4         India   262.6500
# 5       Germany   227.1800
# 6        Russia   188.3300
# 7         Japan   187.3490
# 8        France   114.8200
# 9         Italy   113.9900
# 10           UK   110.0700
# 11        Spain   100.5400
# 12       Turkey    96.6200
# 13       Mexico    56.0200
# 14    Australia    44.6200
# 15    Indonesia    41.6406
# 16     Thailand    30.5401
# 17  South Korea    25.3200
# 18         Iran    15.4500
# 19       Taiwan    12.4000

# %%
countrywisetotal.head(5)
# Out:
#   Country    Total
# 0   China  1819.940
# 1     USA   758.619
# 2  Brazil   466.350
# 3  Canada   424.090
# 4   India   262.650

# %%
countries.groupby("Country")["Total "].sum().sort_values(ascending=False).head(5)
# Out:
# Country
# China     1819.940
# USA        758.619
# Brazil     466.350
# Canada     424.090
# India      262.650
# Name: Total , dtype: float64

# %%
##3	We have BRICS countries in top 20 country list, create a bar chart representing their renewable energy consumption.

# %%
import pandas as pd
import matplotlib.pyplot as plt
countries=pd.read_csv(r"C:\Users\ANJUM AHMED\Downloads\top20CountriesPowerGeneration.csv")
countries
# Out:
#         Country    Hydro   Biofuel  Solar PV  Geothermal (TWh)     Total
# 0         China  1189.84  295.0200     79.43            0.1250  1819.9400
# 1           USA   315.62  277.9100     58.95           18.9600   758.6190
# 2        Brazil   370.90   42.3700     52.25            0.0000   466.3500
# 3        Canada   383.48   29.6500      7.12            0.0000   424.0900
# 4         India   141.80   51.0600     43.76            0.0000   262.6500
# 5       Germany    24.17  111.5900     45.10            0.1600   227.1800
# 6        Russia   187.13    0.1400      0.08            0.4300   188.3300
# 7         Japan    90.67    7.6300     19.01            2.4400   187.3490
# 8        France    70.13   28.5000      5.87            0.1300   114.8200
# 9         Italy    50.92   17.4900     16.85            6.0800   113.9900
# 10           UK     7.96   57.1100     32.08            0.0000   110.0700
# 11        Spain    36.74   50.8100      5.48            0.0000   100.5400
# ...

# %%
brics=countries[(countries.Country=="Brazil")|(countries.Country=="Russia")|(countries.Country=="India")|(countries.Country=="Canada")]
brics
# Out:
#   Country   Hydro  Biofuel  Solar PV  Geothermal (TWh)  Total
# 2  Brazil  370.90    42.37     52.25              0.00  466.35
# 3  Canada  383.48    29.65      7.12              0.00  424.09
# 4   India  141.80    51.06     43.76              0.00  262.65
# 6  Russia  187.13     0.14      0.08              0.43  188.33

# %%
brics1=countries.loc[[2,3,4,6],["Country","Total "]]
brics1
# Out:
#   Country  Total
# 2  Brazil  466.35
# 3  Canada  424.09
# 4   India  262.65
# 6  Russia  188.33

# %%
Total_Consumption=brics.plot.bar(x='Country',y='Total ',color="purple")
Total_Consumption

plt.xlabel("Country")
plt.ylabel("Total")
plt.legend(["Country"])
plt.title('Consumption of BRICS')
# Out:
# Text(0.5, 1.0, 'Consumption of BRICS')

# %%
#4	Create a bar chart representing the solar energy generation of all European countries in top 20 renewable energy country list.

euro_country=countries[(countries.Country=="Turkey")|(countries.Country=="Spain")|(countries.Country=="Germany")|(countries.Country=="Mexico")|(countries.Country=="UK")|(countries.Country=="France")|(countries.Country=="Italy")]
euro_country
# Out:
#     Country  Hydro  Biofuel  Solar PV  Geothermal (TWh)  Total
# 5   Germany  24.17   111.59     45.10              0.16  227.18
# 8    France  70.13    28.50      5.87              0.13  114.82
# 9     Italy  50.92    17.49     16.85              6.08  113.99
# 10       UK   7.96    57.11     32.08              0.00  110.07
# 11    Spain  36.74    50.81      5.48              0.00  100.54
# 12   Turkey  59.74    19.88      2.63              6.90   96.62
# 13   Mexico  32.52    13.07      1.88              5.36   56.02

# %%
euro_solar=euro_country.plot.bar(x='Country',y='Solar PV',color="red",hatch="*")
euro_solar
plt.xlabel("Country")
plt.ylabel("Solar PV")
plt.legend(["Country"])
plt.title('solar pv of europeon countries')
# Out:
# Text(0.5, 1.0, 'solar pv of europeon countries')

# %%
##5	Create a stack plot for India based on renewable energy generation.

# %%
import matplotlib.pyplot as plt
india=countries[(countries.Country=="India")]
india
# Out:
#   Country  Hydro  Biofuel  Solar PV  Geothermal (TWh)  Total
# 4   India  141.8    51.06     43.76               0.0  262.65

# %%
india_renew=india.loc[[4],["Hydro","Biofuel","Solar PV","Geothermal (TWh)"]]
india_renew
# Out:
#    Hydro  Biofuel  Solar PV  Geothermal (TWh)
# 4  141.8    51.06     43.76               0.0

# %%
df=india_renew.plot.area(stacked=True)

##it has single line because for evry particular column the numbr of value is 1

# %%
#6	Create a line graph that shows the trend of total energy consumption of the World from 2000.

# %%
years=pd.read_csv(r"C:\Users\ANJUM AHMED\Downloads\renewablePowerGeneration97-17.csv")
years
# Out:
#     Year  Hydro(TWh)  Biofuel(TWh)  Solar PV (TWh)  Geothermal (TWh)    Total
# 0   2000     2695.85         31.34            0.99             51.98  2780.16
# 1   2001     2638.20         38.45            1.32             51.57  2729.54
# 2   2002     2711.12         52.85            1.58             52.29  2817.84
# 3   2003     2726.33         64.23            2.01             54.09  2846.66
# 4   2004     2894.22         84.43            2.66             56.50  3037.81
# 5   2005     3019.50        103.92            3.92             58.28  3185.62
# 6   2006     3124.34        133.05            5.52             59.61  3322.52
# 7   2007     3165.71        170.83            7.47             62.29  3406.30
# 8   2008     3285.59        221.05           11.92             64.91  3583.47
# 9   2009     3338.82        277.44           20.04             67.03  3703.33
# 10  2010     3530.72        341.38           32.22             68.10  3972.42
# ...

# %%
plt.plot(years['Year'],years['Total'],color='Purple')

plt.title("Total Energy Consumption")
plt.xlabel("Years")
plt.ylabel("Total")
plt.grid(True)
plt.show()

# %%
##7	Create a line graph that shows the trend of solar power generation from 2013.

# %%
years1=years.loc[13:18]
years1
# Out:
#     Year  Hydro(TWh)  Biofuel(TWh)  Solar PV (TWh)  Geothermal (TWh)    Total
# 13  2013     2898.28        646.36          139.64             71.74  3756.02
# 14  2014     3976.01        718.07          190.25             77.52  4961.85
# 15  2015     3989.28        838.31          250.75             80.56  5158.90
# 16  2016     4162.26        958.15          329.14             82.18  5531.73
# 17  2017     4197.29       1127.31          443.55             85.34  5853.49

# %%
plt.plot(years1['Year'],years1['Solar PV (TWh)'],color='green')

plt.title("Solar PV (TWh) energy consumption")
plt.xlabel("Years")
plt.ylabel("Solar PV")
plt.grid(True)
plt.show()

# %%
# 8	On which year the total energy consumption of Asia is highest

# %%
eel=pd.read_csv(r"C:\Users\ANJUM AHMED\Downloads\Continent-Consumption-TWH.csv")
eel
# Out:
#     Year      World      OECD     BRICS    Europe  North America  \
# 0   1990  101855.54  52602.49  26621.07  20654.88       24667.23
# 1   1991  102483.56  53207.25  26434.99  20631.62       24841.68
# 2   1992  102588.23  53788.75  25993.05  20189.68       25341.77
# 3   1993  103646.56  54614.48  26283.80  20189.68       25830.23
# 4   1994  104449.03  55579.77  25993.05  20085.01       26365.21
# 5   1995  107112.30  56754.40  26946.71  20713.03       26714.11
# 6   1996  109763.94  58417.49  27481.69  21445.72       27295.61
# 7   1997  110903.68  59022.25  27446.80  21341.05       27574.73
# 8   1998  111450.29  59219.96  27528.21  21503.87       27772.44
# 9   1999  113974.00  60301.55  28319.05  21306.16       28528.39
# 10  2000  116590.75  61685.52  28923.81  21538.76       29342.49
# 11  2001  117521.15  61452.92  29528.57  21934.18       28795.88
# 12  2002  120207.68  61987.90  30552.01  21969.07       29156.41
# ...

# %%
eel2=eel.loc[:,['Asia','Year']]
eel2
# Out:
#         Asia  Year
# 0   24574.19  1990
# 1   24783.53  1991
# 2   25690.67  1992
# 3   26876.93  1993
# 4   28098.08  1994
# 5   29761.17  1995
# 6   30772.98  1996
# 7   31435.89  1997
# 8   31331.22  1998
# 9   32412.81  1999
# 10  33564.18  2000
# 11  34227.09  2001
# 12  35680.84  2002
# 13  38181.29  2003
# 14  41437.69  2004
# 15  43693.91  2005
# 16  46124.58  2006
# 17  48555.25  2007
# 18  49636.84  2008
# 19  51858.17  2009
# 20  56010.08  2010
# 21  58324.45  2011
# 22  60022.43  2012
# 23  61499.44  2013
# 24  62895.04  2014
# 25  63476.54  2015
# 26  63941.74  2016
# 27  65721.13  2017
# 28  68035.50  2018
# 29  69582.29  2019
# 30  69256.65  2020

# %%
eel5=eel2.groupby("Asia")[["Year"]].max().tail(1)
eel5


##The highest total energy consumption of Asia is at year 2019 i.e 69582.29
# Out:
#           Year
# Asia
# 69582.29  2019

# %%
##9	Create a pie chart which shows the percentage of energy consumption in 2020 on international group level(BRICS,OECD,CIS)

# %%
ener2020=pd.read_csv(r"C:\Users\ANJUM AHMED\Downloads\Continent-Consumption-TWH.csv")
ener2020
# Out:
#     Year      World      OECD     BRICS    Europe  North America  \
# 0   1990  101855.54  52602.49  26621.07  20654.88       24667.23
# 1   1991  102483.56  53207.25  26434.99  20631.62       24841.68
# 2   1992  102588.23  53788.75  25993.05  20189.68       25341.77
# 3   1993  103646.56  54614.48  26283.80  20189.68       25830.23
# 4   1994  104449.03  55579.77  25993.05  20085.01       26365.21
# 5   1995  107112.30  56754.40  26946.71  20713.03       26714.11
# 6   1996  109763.94  58417.49  27481.69  21445.72       27295.61
# 7   1997  110903.68  59022.25  27446.80  21341.05       27574.73
# 8   1998  111450.29  59219.96  27528.21  21503.87       27772.44
# 9   1999  113974.00  60301.55  28319.05  21306.16       28528.39
# 10  2000  116590.75  61685.52  28923.81  21538.76       29342.49
# 11  2001  117521.15  61452.92  29528.57  21934.18       28795.88
# 12  2002  120207.68  61987.90  30552.01  21969.07       29156.41
# ...

# %%
ener2020c=ener2020.loc[[30],["OECD","BRICS","CIS"]]
ener2020c
# Out:
#         OECD     BRICS       CIS
# 30  57487.09  63162.53  11804.45

# %%
totalconsum = ener2020c.sum()
totalconsum
# Out:
# OECD     57487.09
# BRICS    63162.53
# CIS      11804.45
# dtype: float64

# %%
plt.pie(totalconsum, labels=['OECD','BRICS','CIS'],explode=[0,0.1,0.2],autopct="%0.1f%%",shadow=True)
plt.title('Energy Consumption in 2020')
plt.axis('equal') 
plt.show()

# %%
####10	Which are the top 3 non-renewable mode of generation

# %%
top3=pd.read_csv(r"C:\Users\ANJUM AHMED\Downloads\renewablesTotalPowerGeneration.csv")
top3
# Out:
#   Mode of Generation  Contribution (TWh)
# 0              Hydro             9863.33
# 1               Wind             5882.82
# 2            Biofuel             2636.03
# 3           Solar PV              841.87
# 4         Geothermal              114.04
# 5    Renewable waste               74.05
# 6      Solar Thermal               36.02
# 7              Tidal            19448.16

# %%
top3_power=top3.groupby("Mode of Generation")["Contribution (TWh)"].sum().sort_values(ascending=False).head(3)
top3_power
# Out:
# Mode of Generation
# Tidal    19448.16
# Hydro     9863.33
# Wind      5882.82
# Name: Contribution (TWh), dtype: float64

# %%
##11 What is India’s total power consumption from 1990

# %%
country_consumption=pd.read_csv(r"C:\Users\ANJUM AHMED\Downloads\Country_Consumption_TWH (1).csv")
country_consumption
# Out:
#       Year   China  United States  Brazil  Belgium  Czechia  France  Germany  \
# 0   1990.0   874.0         1910.0   141.0     48.0     50.0   225.0    351.0
# 1   1991.0   848.0         1925.0   143.0     50.0     45.0   237.0    344.0
# 2   1992.0   877.0         1964.0   145.0     51.0     44.0   234.0    338.0
# 3   1993.0   929.0         1998.0   148.0     49.0     43.0   238.0    335.0
# 4   1994.0   973.0         2036.0   156.0     52.0     41.0   231.0    333.0
# 5   1995.0  1045.0         2063.0   162.0     53.0     42.0   240.0    336.0
# 6   1996.0  1074.0         2108.0   170.0     56.0     43.0   251.0    348.0
# 7   1997.0  1073.0         2130.0   179.0     56.0     43.0   244.0    345.0
# 8   1998.0  1079.0         2148.0   183.0     57.0     42.0   252.0    343.0
# 9   1999.0  1099.0         2206.0   187.0     57.0     39.0   252.0    335.0
# 10  2000.0  1130.0         2269.0   188.0     58.0     41.0   255.0    337.0
# ...

# %%
india1990=country_consumption.loc[[0],["Year","India"]]
india1990
# Out:
#      Year  India
# 0  1990.0  306.0

# %%
##12	Show the trend of India’s power consumption in last 5 years 2015-2020 using scatter plot or line plot

# %%
country_consumption=pd.read_csv(r"C:\Users\ANJUM AHMED\Downloads\Country_Consumption_TWH (1).csv")
country_consumption
# Out:
#       Year   China  United States  Brazil  Belgium  Czechia  France  Germany  \
# 0   1990.0   874.0         1910.0   141.0     48.0     50.0   225.0    351.0
# 1   1991.0   848.0         1925.0   143.0     50.0     45.0   237.0    344.0
# 2   1992.0   877.0         1964.0   145.0     51.0     44.0   234.0    338.0
# 3   1993.0   929.0         1998.0   148.0     49.0     43.0   238.0    335.0
# 4   1994.0   973.0         2036.0   156.0     52.0     41.0   231.0    333.0
# 5   1995.0  1045.0         2063.0   162.0     53.0     42.0   240.0    336.0
# 6   1996.0  1074.0         2108.0   170.0     56.0     43.0   251.0    348.0
# 7   1997.0  1073.0         2130.0   179.0     56.0     43.0   244.0    345.0
# 8   1998.0  1079.0         2148.0   183.0     57.0     42.0   252.0    343.0
# 9   1999.0  1099.0         2206.0   187.0     57.0     39.0   252.0    335.0
# 10  2000.0  1130.0         2269.0   188.0     58.0     41.0   255.0    337.0
# ...

# %%
india15_20=country_consumption.loc[25:30,["Year","India"]]
india15_20
# Out:
#       Year  India
# 25  2015.0  835.0
# 26  2016.0  852.0
# 27  2017.0  883.0
# 28  2018.0  919.0
# 29  2019.0  940.0
# 30  2020.0  908.0

# %%
plt.plot(india15_20['Year'],india15_20['India'],color='Brown')

plt.title("India consumption from 2015-2020")
plt.xlabel("Year")
plt.ylabel("India")
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# %%
sns.jointplot(data=country_consumption,x="Year",y="India")

# %%
##13	Which country has the lowest power consumption on 2020

# %%
lowest2020=country_consumption.loc[30]
lowest2020
# Out:
# Year                    2020.0
# China                   3381.0
# United States           2046.0
# Brazil                   286.0
# Belgium                   51.0
# Czechia                   39.0
# France                   217.0
# Germany                  275.0
# Italy                    137.0
# Netherlands               70.0
# Poland                    97.0
# Portugal                  20.0
# Romania                   32.0
# Spain                    107.0
# Sweden                    47.0
# United Kingdom           154.0
# Norway                    27.0
# Turkey                   141.0
# Kazakhstan                70.0
# Russia                   731.0
# Ukraine                   86.0
# Uzbekistan                44.0
# Argentina                 72.0
# Canada                   281.0
# Chile                     38.0
# Colombia                  39.0
# Mexico                   151.0
# Venezuela                 29.0
# Indonesia                225.0
# Japan                    386.0
# ...

# %%
lowest2020value=pd.read_excel(r"C:\Users\ANJUM AHMED\Downloads\Book2323.xlsx")
lowest2020value
# Out:
#                               Year  values
# 0   China                   3381.0  3381.0
# 1   United States           2046.0  2046.0
# 2   Brazil                   286.0   286.0
# 3   Belgium                   51.0    51.0
# 4   Czechia                   39.0    39.0
# 5   France                   217.0   217.0
# 6   Germany                  275.0   275.0
# 7   Italy                    137.0   137.0
# 8   Netherlands               70.0    70.0
# 9   Poland                    97.0    97.0
# 10  Portugal                  20.0    20.0
# 11  Romania                   32.0    32.0
# 12  Spain                    107.0   107.0
# 13  Sweden                    47.0    47.0
# 14  United Kingdom           154.0   154.0
# 15  Norway                    27.0    27.0
# 16  Turkey                   141.0   141.0
# 17  Kazakhstan                70.0    70.0
# 18  Russia                   731.0   731.0
# 19  Ukraine                   86.0    86.0
# 20  Uzbekistan                44.0    44.0
# ...

# %%
lowest2020value.groupby("Year")["values"].sum().sort_values(ascending=False).tail(1)


##the country with lowest energy consumption is PORTUGAL
# Out:
# Year
# Portugal                  20.0    20.0
# Name: values, dtype: float64

# %%
##14 What is the average hydro power generation from (1990-2017)

# %%
hydro=pd.read_csv(r"C:\Users\ANJUM AHMED\Downloads\renewablePowerGeneration97-17 (1).csv")
hydro
# Out:
#     Year  Hydro(TWh)  Biofuel(TWh)  Solar PV (TWh)  Geothermal (TWh)
# 0   1990     2191.67          3.88            0.09             36.42
# 1   1991     2268.63          4.19            0.10             37.39
# 2   1992     2267.16          4.63            0.12             39.30
# 3   1993     2397.67          5.61            0.15             40.23
# 4   1994     2419.73          7.31            0.17             41.05
# 5   1995     2545.96          7.95            0.19             39.89
# 6   1996     2583.18          9.45            0.22             42.18
# 7   1997     2614.54         12.08            0.27             42.38
# 8   1998     2628.63         16.07            0.35             45.35
# 9   1999     2636.26         21.52            0.61             48.66
# 10  2000     2695.85         31.34            0.99             51.98
# 11  2001     2638.20         38.45            1.32             51.57
# 12  2002     2711.12         52.85            1.58             52.29
# ...

# %%
H_ydro=hydro.loc[:,["Year","Hydro(TWh)"]]
H_ydro
# Out:
#     Year  Hydro(TWh)
# 0   1990     2191.67
# 1   1991     2268.63
# 2   1992     2267.16
# 3   1993     2397.67
# 4   1994     2419.73
# 5   1995     2545.96
# 6   1996     2583.18
# 7   1997     2614.54
# 8   1998     2628.63
# 9   1999     2636.26
# 10  2000     2695.85
# 11  2001     2638.20
# 12  2002     2711.12
# 13  2003     2726.33
# 14  2004     2894.22
# 15  2005     3019.50
# 16  2006     3124.34
# 17  2007     3165.71
# 18  2008     3285.59
# 19  2009     3338.82
# 20  2010     3530.72
# 21  2011     2603.78
# 22  2012     3765.96
# 23  2013     2898.28
# 24  2014     3976.01
# 25  2015     3989.28
# 26  2016     4162.26
# 27  2017     4197.29

# %%
average=H_ydro['Hydro(TWh)'].mean()
average
# Out:
# 2974.1674999999996

# %%
average=H_ydro['Year'].mean()
average
# Out:
# 2003.5

# %%
#15	Looking at India’s number in total renewable power generation. Do you think India has more potential in improving its renewable power capacity? and why? (50 words)

# %% [raw]
# # Yes, India has tremendous potential for improving its renewable power capacity and continue its transition towards a sustainable and cleaner energy future.India is blessed with abundant solar, wind, biomass, and hydro resources. The country’s geographical diversity allows for the harnessing of different renewable energy sources across various regions, providing ample opportunities for further development.he Indian government has been proactive in promoting renewable energy through various policies, targets, and incentives. Initiatives like the National Solar Mission and the Wind Energy Mission aim to expand renewable energy capacity and drive investments in the sector.The cost of renewable energy technologies, particularly solar and wind, has been steadily declining over the years. This cost reduction makes renewable power more competitive and economically viable, encouraging further investment and capacity expansion.India’s energy demand is expected to continue growing due to its population growth and expanding economy. Renewable energy can play a crucial role in meeting this increasing demand while reducing reliance on fossil fuels and addressing environmental concerns.The renewable energy sector has the potential to create jobs and stimulate economic growth. India has recognized this and aims to generate employment opportunities through the development of renewable power projects, contributing to both social and economic development.
